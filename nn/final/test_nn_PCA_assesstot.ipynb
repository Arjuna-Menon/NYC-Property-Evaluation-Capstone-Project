# %%
import nn_functions
import pandas as pd
# Out:
# Using TensorFlow backend.

# %%
x_train, x_test, y_train, y_test, predictors = nn_functions.get_data('../../plutoPCA_tot.csv','assesstot')

# %%
input_nodes = len(predictors)
print('input_nodes', input_nodes)
epochs = 30
hidden_nodes = [int((input_nodes+1)*(2/3)), int(len(x_train)/(30*2)), int(len(x_train)/(30*4)), int(len(x_train)/(30*6)), int(len(x_train)/(30*8))]
optimizers = ['rmsprop', 'adam','adagrad','adadelta']
h = []
o = []
df_models = pd.DataFrame()
for i in hidden_nodes:
    for j in optimizers:
        h.append(i)
        o.append(j)
        
df_models['hidden_nodes'] = h
df_models['optimizer']  = o
df_models
# Out:
# input_nodes 170
#     hidden_nodes optimizer
# 0            114   rmsprop
# 1            114      adam
# 2            114   adagrad
# 3            114  adadelta
# 4            207   rmsprop
# 5            207      adam
# 6            207   adagrad
# 7            207  adadelta
# 8            103   rmsprop
# 9            103      adam
# 10           103   adagrad
# 11           103  adadelta
# 12            69   rmsprop
# 13            69      adam
# 14            69   adagrad
# 15            69  adadelta
# 16            51   rmsprop
# 17            51      adam
# 18            51   adagrad
# 19            51  adadelta

# %%
mse_list = []
rmse_list = []
r2_list = []
error_list = []
for index, row in df_models.iterrows():
    try:
        print('Model:', index, 'hidden_nodes:', row['hidden_nodes'], 'optimizer:', row['optimizer'])
        y_train_pred, y_test_pred, mse,rmse,r2,error = nn_functions.run_model(input_nodes, row['hidden_nodes'], x_train, x_test, y_train, y_test, row['optimizer'], epochs)
    except Exception as ex:
        print(ex)
        mse = float('nan')
        rmse = float('nan')
        r2 = float('nan')
        error = float('nan')
        print('Error while computing model: ', index)
    mse_list.append(mse)
    rmse_list.append(rmse)
    r2_list.append(r2)
    error_list.append(error)
        
df_models['mse'] = mse_list
df_models['rmse'] = rmse_list
df_models['r2'] = r2_list
df_models['error'] = error_list
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0801 20:48:10.512250 4442817984 deprecation.py:323] From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Model: 0 hidden_nodes: 114 optimizer: rmsprop
# ERROR Training
# mse 36551551959.606
# RMSE 191184.602
# R2 0.676
# error 8676.204426486276
# ERROR Test
# mse 30765596599.688
# RMSE 175401.245
# R2 0.673
# error 8614.542838648173
# Model: 1 hidden_nodes: 114 optimizer: adam
# ERROR Training
# mse 34534434973.378
# RMSE 185834.429
# R2 0.694
# error 7296.6565669854435
# ERROR Test
# mse 28886225507.244
# RMSE 169959.482
# R2 0.693
# error 7262.732759784088
# Model: 2 hidden_nodes: 114 optimizer: adagrad
# ERROR Training
# mse 121872268991.087
# RMSE 349102.09
# R2 -0.079
# error 96723.84061640223
# ERROR Test
# mse 102728788162.555
# RMSE 320513.32
# R2 -0.093
# error 95769.76835876062
# Model: 3 hidden_nodes: 114 optimizer: adadelta
# ERROR Training
# mse 122424152288.331
# RMSE 349891.629
# R2 -0.084
# error 97182.43136148529
# ERROR Test
# mse 103240725049.693
# RMSE 321310.948
# R2 -0.099
# error 96239.40464831775
# Model: 4 hidden_nodes: 207 optimizer: rmsprop
# ERROR Training
# mse 35592506934.832
# RMSE 188659.765
# R2 0.685
# error 7864.80137435113
# ERROR Test
# mse 30027141869.491
# RMSE 173283.415
# R2 0.68
# error 7580.985253226956
# Model: 5 hidden_nodes: 207 optimizer: adam
# ERROR Training
# mse 33982883379.146
# RMSE 184344.469
# R2 0.699
# error 8357.561028405271
# ERROR Test
# mse 28865828887.923
# RMSE 169899.467
# R2 0.693
# error 8108.319154637124
# Model: 6 hidden_nodes: 207 optimizer: adagrad
# ERROR Training
# mse 121343687550.744
# RMSE 348344.208
# R2 -0.074
# error 96243.24137707546
# ERROR Test
# mse 102244597982.985
# RMSE 319757.092
# R2 -0.088
# error 95283.21228859414
# Model: 7 hidden_nodes: 207 optimizer: adadelta
# ERROR Training
# mse 122423686982.236
# RMSE 349890.964
# R2 -0.084
# error 97182.03577933888
# ERROR Test
# mse 103240279864.753
# RMSE 321310.255
# R2 -0.099
# error 96238.98155512587
# Model: 8 hidden_nodes: 103 optimizer: rmsprop
# ERROR Training
# mse 36008977394.732
# RMSE 189760.316
# R2 0.681
# error 7590.090134476864
# ERROR Test
# mse 30222497719.852
# RMSE 173846.19
# R2 0.678
# error 7464.384857806153
# Model: 9 hidden_nodes: 103 optimizer: adam
# ERROR Training
# mse 34769723960.832
# RMSE 186466.415
# R2 0.692
# error 7128.342008224207
# ERROR Test
# mse 29214799154.359
# RMSE 170923.372
# R2 0.689
# error 7045.226675605529
# Model: 10 hidden_nodes: 103 optimizer: adagrad
# ERROR Training
# mse 121910287712.645
# RMSE 349156.538
# R2 -0.079
# error 96745.45198594198
# ERROR Test
# mse 102761864986.403
# RMSE 320564.915
# R2 -0.093
# error 95792.34129192146
# Model: 11 hidden_nodes: 103 optimizer: adadelta
# ERROR Training
# mse 122424432578.755
# RMSE 349892.03
# R2 -0.084
# error 97183.18415540304
# ERROR Test
# mse 103240975142.288
# RMSE 321311.337
# R2 -0.099
# error 96240.15521594079
# Model: 12 hidden_nodes: 69 optimizer: rmsprop
# ERROR Training
# mse 37468025924.27
# RMSE 193566.593
# R2 0.668
# error 9235.864990829847
# ERROR Test
# mse 31088072394.88
# RMSE 176318.1
# R2 0.669
# error 9274.3362492349
# Model: 13 hidden_nodes: 69 optimizer: adam
# ERROR Training
# mse 35035398812.493
# RMSE 187177.453
# R2 0.69
# error 7406.090829318154
# ERROR Test
# mse 29320554781.052
# RMSE 171232.458
# R2 0.688
# error 7465.231943035371
# Model: 14 hidden_nodes: 69 optimizer: adagrad
# ERROR Training
# mse 122081533227.263
# RMSE 349401.679
# R2 -0.081
# error 96899.39956511579
# ERROR Test
# mse 102921302647.161
# RMSE 320813.501
# R2 -0.095
# error 95948.96051672017
# Model: 15 hidden_nodes: 69 optimizer: adadelta
# ERROR Training
# mse 122424196791.425
# RMSE 349891.693
# R2 -0.084
# error 97182.37076679642
# ERROR Test
# mse 103240730276.632
# RMSE 321310.956
# R2 -0.099
# error 96239.31446039098
# Model: 16 hidden_nodes: 51 optimizer: rmsprop
# ERROR Training
# mse 38435415644.944
# RMSE 196049.523
# R2 0.66
# error 14369.613872326261
# ERROR Test
# mse 31758653958.282
# RMSE 178209.579
# R2 0.662
# error 14159.511347472437
# Model: 17 hidden_nodes: 51 optimizer: adam
# ERROR Training
# mse 35398317738.34
# RMSE 188144.407
# R2 0.687
# error 7319.457431801808
# ERROR Test
# mse 29535341534.304
# RMSE 171858.493
# R2 0.686
# error 7376.415575025011
# Model: 18 hidden_nodes: 51 optimizer: adagrad
# ERROR Training
# mse 122215763000.764
# RMSE 349593.711
# R2 -0.082
# error 96997.05946501928
# ERROR Test
# mse 103048023736.076
# RMSE 321010.94
# R2 -0.096
# error 96051.0933424066
# Model: 19 hidden_nodes: 51 optimizer: adadelta
# ERROR Training
# mse 122424091619.729
# RMSE 349891.543
# R2 -0.084
# error 97182.10242924596
# ERROR Test
# mse 103240670139.915
# RMSE 321310.862
# R2 -0.099
# error 96239.07045763501

# %%
max_r2 = df_models['r2'].idxmax(axis=0, skipna=True)
print('Max r2:', max_r2)
print(df_models.loc[max_r2])
min_rmse = df_models['rmse'].idxmin(axis=0, skipna=True)
print('Min rmse:', min_rmse)
print(df_models.loc[min_rmse])
df_models
# Out:
# Max r2: 1
# hidden_nodes            114
# optimizer              adam
# mse             2.88862e+10
# rmse                 169959
# r2                    0.693
# error               7262.73
# Name: 1, dtype: object
# Min rmse: 5
# hidden_nodes            207
# optimizer              adam
# mse             2.88658e+10
# rmse                 169899
# r2                    0.693
# error               8108.32
# Name: 5, dtype: object
#     hidden_nodes optimizer           mse        rmse     r2         error
# 0            114   rmsprop  3.076560e+10  175401.245  0.673   8614.542839
# 1            114      adam  2.888623e+10  169959.482  0.693   7262.732760
# 2            114   adagrad  1.027288e+11  320513.320 -0.093  95769.768359
# 3            114  adadelta  1.032407e+11  321310.948 -0.099  96239.404648
# 4            207   rmsprop  3.002714e+10  173283.415  0.680   7580.985253
# 5            207      adam  2.886583e+10  169899.467  0.693   8108.319155
# 6            207   adagrad  1.022446e+11  319757.092 -0.088  95283.212289
# 7            207  adadelta  1.032403e+11  321310.255 -0.099  96238.981555
# 8            103   rmsprop  3.022250e+10  173846.190  0.678   7464.384858
# 9            103      adam  2.921480e+10  170923.372  0.689   7045.226676
# 10           103   adagrad  1.027619e+11  320564.915 -0.093  95792.341292
# 11           103  adadelta  1.032410e+11  321311.337 -0.099  96240.155216
# 12            69   rmsprop  3.108807e+10  176318.100  0.669   9274.336249
# 13            69      adam  2.932055e+10  171232.458  0.688   7465.231943
# 14            69   adagrad  1.029213e+11  320813.501 -0.095  95948.960517
# 15            69  adadelta  1.032407e+11  321310.956 -0.099  96239.314460
# 16            51   rmsprop  3.175865e+10  178209.579  0.662  14159.511347
# 17            51      adam  2.953534e+10  171858.493  0.686   7376.415575
# 18            51   adagrad  1.030480e+11  321010.940 -0.096  96051.093342
# 19            51  adadelta  1.032407e+11  321310.862 -0.099  96239.070458

# %%
print(input_nodes)
# Out:
# 170
