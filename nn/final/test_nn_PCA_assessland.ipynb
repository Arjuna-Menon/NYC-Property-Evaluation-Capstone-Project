# %%
import nn_functions
import pandas as pd

# %%
x_train, x_test, y_train, y_test, predictors = nn_functions.get_data('../../plutoPCA_land.csv','assessland')

# %%
input_nodes = len(predictors)
epochs = 10
hidden_nodes = [int((input_nodes+1)*(2/3)), int(len(x_train)/(30*2)), int(len(x_train)/(30*4)), int(len(x_train)/(30*6)), int(len(x_train)/(30*8))]
optimizers = ['rmsprop', 'adam','adagrad','adadelta']
h = []
o = []
df_models = pd.DataFrame()
for i in hidden_nodes:
    for j in optimizers:
        h.append(i)
        o.append(j)
        
df_models['hidden_nodes'] = h
df_models['optimizer']  = o
df_models
# Out:
#     hidden_nodes optimizer
# 0            114   rmsprop
# 1            114      adam
# 2            114   adagrad
# 3            114  adadelta
# 4            207   rmsprop
# 5            207      adam
# 6            207   adagrad
# 7            207  adadelta
# 8            103   rmsprop
# 9            103      adam
# 10           103   adagrad
# 11           103  adadelta
# 12            69   rmsprop
# 13            69      adam
# 14            69   adagrad
# 15            69  adadelta
# 16            51   rmsprop
# 17            51      adam
# 18            51   adagrad
# 19            51  adadelta

# %%
mse_list = []
rmse_list = []
r2_list = []
error_list = []
for index, row in df_models.iterrows():
    try:
        print('Model:', index, 'hidden_nodes:', row['hidden_nodes'], 'optimizer:', row['optimizer'])
        y_train_pred, y_test_pred, mse,rmse,r2,error = nn_functions.run_model(input_nodes, row['hidden_nodes'], x_train, x_test, y_train, y_test, row['optimizer'], epochs)
    except Exception as ex:
        print(ex)
        mse = float('nan')
        rmse = float('nan')
        r2 = float('nan')
        error = float('nan')
        print('Error while computing model: ', index)
    mse_list.append(mse)
    rmse_list.append(rmse)
    r2_list.append(r2)
    error_list.append(error)
        
df_models['mse'] = mse_list
df_models['rmse'] = rmse_list
df_models['r2'] = r2_list
df_models['error'] = error_list
# Out:
# Model: 0 hidden_nodes: 114 optimizer: rmsprop
# ERROR Training
# mse 2503660112.56
# RMSE 50036.588
# R2 0.463
# error 3450.045199108241
# ERROR Test
# mse 1842555939.5
# RMSE 42925.004
# R2 0.454
# error 2917.797526791596
# Model: 1 hidden_nodes: 114 optimizer: adam
# ERROR Training
# mse 2385536334.868
# RMSE 48841.953
# R2 0.489
# error 2011.334356687366
# ERROR Test
# mse 1888807598.308
# RMSE 43460.414
# R2 0.44
# error 1477.3886635189965
# Model: 2 hidden_nodes: 114 optimizer: adagrad
# ERROR Training
# mse 5132275237.656
# RMSE 71639.9
# R2 -0.1
# error 21804.46571284654
# ERROR Test
# mse 3837952004.08
# RMSE 61951.207
# R2 -0.138
# error 21783.154984788172
# Model: 3 hidden_nodes: 114 optimizer: adadelta
# ERROR Training
# mse 5145612842.736
# RMSE 71732.927
# R2 -0.103
# error 21892.56183501502
# ERROR Test
# mse 3850678737.088
# RMSE 62053.837
# R2 -0.142
# error 21873.508652849392
# Model: 4 hidden_nodes: 207 optimizer: rmsprop
# ERROR Training
# mse 2400635156.835
# RMSE 48996.277
# R2 0.486
# error 1714.0114002351904
# ERROR Test
# mse 1861917192.914
# RMSE 43149.939
# R2 0.448
# error 1130.6862455970838
# Model: 5 hidden_nodes: 207 optimizer: adam
# ERROR Training
# mse 2332966037.791
# RMSE 48300.787
# R2 0.5
# error 2104.6970279148472
# ERROR Test
# mse 1915076953.08
# RMSE 43761.592
# R2 0.432
# error 1493.4448944003425
# Model: 6 hidden_nodes: 207 optimizer: adagrad
# ERROR Training
# mse 5116934768.733
# RMSE 71532.753
# R2 -0.097
# error 21704.359876723138
# ERROR Test
# mse 3822751240.743
# RMSE 61828.402
# R2 -0.134
# error 21678.486220795025
# Model: 7 hidden_nodes: 207 optimizer: adadelta
# ERROR Training
# mse 5145597431.059
# RMSE 71732.82
# R2 -0.103
# error 21892.63394477582
# ERROR Test
# mse 3850665848.086
# RMSE 62053.734
# R2 -0.142
# error 21873.57211276779
# Model: 8 hidden_nodes: 103 optimizer: rmsprop
# ERROR Training
# mse 2501732887.48
# RMSE 50017.326
# R2 0.464
# error 3386.60281908397
# ERROR Test
# mse 1830025447.567
# RMSE 42778.797
# R2 0.457
# error 2850.910385684579
# Model: 9 hidden_nodes: 103 optimizer: adam
# ERROR Training
# mse 2404769666.849
# RMSE 49038.451
# R2 0.485
# error 2408.701798653733
# ERROR Test
# mse 1881575849.435
# RMSE 43377.135
# R2 0.442
# error 1850.2876278197289
# Model: 10 hidden_nodes: 103 optimizer: adagrad
# ERROR Training
# mse 5133080816.16
# RMSE 71645.522
# R2 -0.1
# error 21812.258596734206
# ERROR Test
# mse 3838680718.145
# RMSE 61957.088
# R2 -0.138
# error 21790.970719662193
# Model: 11 hidden_nodes: 103 optimizer: adadelta
# ERROR Training
# mse 5145612343.184
# RMSE 71732.924
# R2 -0.103
# error 21892.597140050962
# ERROR Test
# mse 3850679416.254
# RMSE 62053.843
# R2 -0.142
# error 21873.533347851237
# Model: 12 hidden_nodes: 69 optimizer: rmsprop
# ERROR Training
# mse 2587374293.935
# RMSE 50866.239
# R2 0.446
# error 3896.543565549103
# ERROR Test
# mse 1834353850.284
# RMSE 42829.357
# R2 0.456
# error 3367.6500044364766
# Model: 13 hidden_nodes: 69 optimizer: adam
# ERROR Training
# mse 2431714613.645
# RMSE 49312.418
# R2 0.479
# error 3111.070389305285
# ERROR Test
# mse 1905988737.357
# RMSE 43657.631
# R2 0.435
# error 2510.4491676541293
# Model: 14 hidden_nodes: 69 optimizer: adagrad
# ERROR Training
# mse 5138268833.777
# RMSE 71681.719
# R2 -0.101
# error 21843.489673325446
# ERROR Test
# mse 3843458386.53
# RMSE 61995.632
# R2 -0.14
# error 21822.551609113416
# Model: 15 hidden_nodes: 69 optimizer: adadelta
# ERROR Training
# mse 5145624336.254
# RMSE 71733.007
# R2 -0.103
# error 21892.71509583906
# ERROR Test
# mse 3850689727.22
# RMSE 62053.926
# R2 -0.142
# error 21873.662541438684
# Model: 16 hidden_nodes: 51 optimizer: rmsprop
# ERROR Training
# mse 2626096874.635
# RMSE 51245.457
# R2 0.437
# error 3302.459044173748
# ERROR Test
# mse 1812117122.462
# RMSE 42568.969
# R2 0.463
# error 2732.637983917883
# Model: 17 hidden_nodes: 51 optimizer: adam
# ERROR Training
# mse 2487671134.565
# RMSE 49876.559
# R2 0.467
# error 2945.130770754423
# ERROR Test
# mse 1845139486.634
# RMSE 42955.087
# R2 0.453
# error 2348.1601630489954
# Model: 18 hidden_nodes: 51 optimizer: adagrad
# ERROR Training
# mse 5138753155.092
# RMSE 71685.097
# R2 -0.101
# error 21845.843999259818
# ERROR Test
# mse 3844135003.086
# RMSE 62001.089
# R2 -0.14
# error 21825.734776717873
# Model: 19 hidden_nodes: 51 optimizer: adadelta
# ERROR Training
# mse 5145611583.946
# RMSE 71732.918
# R2 -0.103
# error 21892.470360584273
# ERROR Test
# mse 3850679111.597
# RMSE 62053.84
# R2 -0.142
# error 21873.41497502931

# %%
max_r2 = df_models[df_models['r2']>0]['r2'].idxmax(axis=0, skipna=True)
print('Max r2:', max_r2)
print(df_models.loc[max_r2])
min_rmse = df_models['rmse'].idxmin(axis=0, skipna=True)
print('Min rmse:', min_rmse)
print(df_models.loc[min_rmse])
df_models
# Out:
# Max r2: 16
# hidden_nodes             51
# optimizer           rmsprop
# mse             1.81212e+09
# rmse                  42569
# r2                    0.463
# error               2732.64
# Name: 16, dtype: object
# Min rmse: 16
# hidden_nodes             51
# optimizer           rmsprop
# mse             1.81212e+09
# rmse                  42569
# r2                    0.463
# error               2732.64
# Name: 16, dtype: object
#     hidden_nodes optimizer           mse       rmse     r2         error
# 0            114   rmsprop  1.842556e+09  42925.004  0.454   2917.797527
# 1            114      adam  1.888808e+09  43460.414  0.440   1477.388664
# 2            114   adagrad  3.837952e+09  61951.207 -0.138  21783.154985
# 3            114  adadelta  3.850679e+09  62053.837 -0.142  21873.508653
# 4            207   rmsprop  1.861917e+09  43149.939  0.448   1130.686246
# 5            207      adam  1.915077e+09  43761.592  0.432   1493.444894
# 6            207   adagrad  3.822751e+09  61828.402 -0.134  21678.486221
# 7            207  adadelta  3.850666e+09  62053.734 -0.142  21873.572113
# 8            103   rmsprop  1.830025e+09  42778.797  0.457   2850.910386
# 9            103      adam  1.881576e+09  43377.135  0.442   1850.287628
# 10           103   adagrad  3.838681e+09  61957.088 -0.138  21790.970720
# 11           103  adadelta  3.850679e+09  62053.843 -0.142  21873.533348
# 12            69   rmsprop  1.834354e+09  42829.357  0.456   3367.650004
# 13            69      adam  1.905989e+09  43657.631  0.435   2510.449168
# 14            69   adagrad  3.843458e+09  61995.632 -0.140  21822.551609
# 15            69  adadelta  3.850690e+09  62053.926 -0.142  21873.662541
# 16            51   rmsprop  1.812117e+09  42568.969  0.463   2732.637984
# 17            51      adam  1.845139e+09  42955.087  0.453   2348.160163
# 18            51   adagrad  3.844135e+09  62001.089 -0.140  21825.734777
# 19            51  adadelta  3.850679e+09  62053.840 -0.142  21873.414975

# %%
df_models2 = df_models.copy()
df_models2.drop(16, axis=0, inplace=True)
df_models2.drop(8, axis=0, inplace=True)
df_models2.drop(12, axis=0, inplace=True)
max_r2 = df_models2[df_models['r2']>0]['r2'].idxmax(axis=0, skipna=True)
print('Max r2:', max_r2)
print(df_models2.loc[max_r2])
min_rmse = df_models2['rmse'].idxmin(axis=0, skipna=True)
print('Min rmse:', min_rmse)
print(df_models2.loc[min_rmse])
df_models2
# Out:
# Min r2: 0
# hidden_nodes            114
# optimizer           rmsprop
# mse             1.84256e+09
# rmse                  42925
# r2                    0.454
# error                2917.8
# Name: 0, dtype: object
# Min rmse: 0
# hidden_nodes            114
# optimizer           rmsprop
# mse             1.84256e+09
# rmse                  42925
# r2                    0.454
# error                2917.8
# Name: 0, dtype: object
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   """
#     hidden_nodes optimizer           mse       rmse     r2         error
# 0            114   rmsprop  1.842556e+09  42925.004  0.454   2917.797527
# 1            114      adam  1.888808e+09  43460.414  0.440   1477.388664
# 2            114   adagrad  3.837952e+09  61951.207 -0.138  21783.154985
# 3            114  adadelta  3.850679e+09  62053.837 -0.142  21873.508653
# 4            207   rmsprop  1.861917e+09  43149.939  0.448   1130.686246
# 5            207      adam  1.915077e+09  43761.592  0.432   1493.444894
# 6            207   adagrad  3.822751e+09  61828.402 -0.134  21678.486221
# 7            207  adadelta  3.850666e+09  62053.734 -0.142  21873.572113
# 9            103      adam  1.881576e+09  43377.135  0.442   1850.287628
# 10           103   adagrad  3.838681e+09  61957.088 -0.138  21790.970720
# 11           103  adadelta  3.850679e+09  62053.843 -0.142  21873.533348
# 13            69      adam  1.905989e+09  43657.631  0.435   2510.449168
# 14            69   adagrad  3.843458e+09  61995.632 -0.140  21822.551609
# 15            69  adadelta  3.850690e+09  62053.926 -0.142  21873.662541
# 17            51      adam  1.845139e+09  42955.087  0.453   2348.160163
# 18            51   adagrad  3.844135e+09  62001.089 -0.140  21825.734777
# 19            51  adadelta  3.850679e+09  62053.840 -0.142  21873.414975

# %%
df_models
# Out:
#     hidden_nodes optimizer           mse       rmse     r2         error
# 0            114   rmsprop  1.842556e+09  42925.004  0.454   2917.797527
# 1            114      adam  1.888808e+09  43460.414  0.440   1477.388664
# 2            114   adagrad  3.837952e+09  61951.207 -0.138  21783.154985
# 3            114  adadelta  3.850679e+09  62053.837 -0.142  21873.508653
# 4            207   rmsprop  1.861917e+09  43149.939  0.448   1130.686246
# 5            207      adam  1.915077e+09  43761.592  0.432   1493.444894
# 6            207   adagrad  3.822751e+09  61828.402 -0.134  21678.486221
# 7            207  adadelta  3.850666e+09  62053.734 -0.142  21873.572113
# 8            103   rmsprop  1.830025e+09  42778.797  0.457   2850.910386
# 9            103      adam  1.881576e+09  43377.135  0.442   1850.287628
# 10           103   adagrad  3.838681e+09  61957.088 -0.138  21790.970720
# 11           103  adadelta  3.850679e+09  62053.843 -0.142  21873.533348
# 12            69   rmsprop  1.834354e+09  42829.357  0.456   3367.650004
# 13            69      adam  1.905989e+09  43657.631  0.435   2510.449168
# 14            69   adagrad  3.843458e+09  61995.632 -0.140  21822.551609
# 15            69  adadelta  3.850690e+09  62053.926 -0.142  21873.662541
# 16            51   rmsprop  1.812117e+09  42568.969  0.463   2732.637984
# 17            51      adam  1.845139e+09  42955.087  0.453   2348.160163
# 18            51   adagrad  3.844135e+09  62001.089 -0.140  21825.734777
# 19            51  adadelta  3.850679e+09  62053.840 -0.142  21873.414975

# %%
input_nodes
# Out:
# 170
